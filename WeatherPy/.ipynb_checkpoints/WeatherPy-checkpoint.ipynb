# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 596

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Specify url
url = "http://api.openweathermap.org/data/2.5/weather?"

# %%
# Initialize variable and parameters
record = 0
set = 1
city_name =[]
lat = []
lon = []
temp = []
cloud = []
humidity = []
wind_speed = []
date = []

# Print header of log
print("Beginning Data Retrieval")
print("-----------------------------")

# Loop through cities randomly chosen and retrieve their weather information from the api
for city in cities:
    query_url = url + "&q=" + city.capitalize() +"&APPID=" + api_key
   
    # Request weather from api
    pull = requests.get(query_url).json()
    
    # Pull information from the api if city weather available in the api
    try:
        
        # Store latitude, temp, cloudiness, and wind speed in separate variables
        city_name.append(pull["name"])
        lat.append(pull["coord"]["lat"])
        lon.append(pull["coord"]["lon"])
        temp.append(pull["main"]["temp"])
        cloud.append(pull["clouds"]["all"])
        humidity.append(pull["main"]["humidity"])
        wind_speed.append(pull["wind"]["speed"])
        date.append(time.ctime(pull["dt"]))        
        
        # Keep record count, group 50 records in each set
        # Print out the record no. in each set, set number, and city name
        if record <= 50:
            print(f"Processing Record {record} of Set {set}  | {city}")
            record += 1
        else:
            record = 0
            set += 1
            print(f"Processing Record {record} of Set {set}  | {city}")
    
    # Print following message when city data is not found
    except KeyError:
        print("City not found. Skipping...")

# Print end of log
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0 of Set 1  | roura
# Processing Record 1 of Set 1  | rio gallegos
# Processing Record 2 of Set 1  | saskylakh
# Processing Record 3 of Set 1  | leningradskiy
# City not found. Skipping...
# Processing Record 4 of Set 1  | cape town
# Processing Record 5 of Set 1  | kapaa
# Processing Record 6 of Set 1  | okhotsk
# Processing Record 7 of Set 1  | timizart
# Processing Record 8 of Set 1  | faanui
# Processing Record 9 of Set 1  | senneterre
# Processing Record 10 of Set 1  | mathbaria
# Processing Record 11 of Set 1  | albany
# Processing Record 12 of Set 1  | ibra
# Processing Record 13 of Set 1  | chokurdakh
# Processing Record 14 of Set 1  | rikitea
# Processing Record 15 of Set 1  | san quintin
# Processing Record 16 of Set 1  | bluff
# Processing Record 17 of Set 1  | dargaville
# Processing Record 18 of Set 1  | seydi
# Processing Record 19 of Set 1  | kulachi
# Processing Record 20 of Set 1  | iskateley
# Processing Record 21 of Set 1  | hermanus
# Processing Record 22 of Set 1  | torrijos
# Processing Record 23 of Set 1  | busselton
# Processing Record 24 of Set 1  | butaritari
# Processing Record 25 of Set 1  | punta arenas
# Processing Record 26 of Set 1  | ushuaia
# Processing Record 27 of Set 1  | dikson
# Processing Record 28 of Set 1  | new norfolk
# Processing Record 29 of Set 1  | aasiaat
# Processing Record 30 of Set 1  | itarema
# Processing Record 31 of Set 1  | vestmannaeyjar
# Processing Record 32 of Set 1  | biskamzha
# Processing Record 33 of Set 1  | moranbah
# Processing Record 34 of Set 1  | oranjemund
# Processing Record 35 of Set 1  | avarua
# Processing Record 36 of Set 1  | east london
# Processing Record 37 of Set 1  | kodiak
# Processing Record 38 of Set 1  | gazli
# Processing Record 39 of Set 1  | hithadhoo
# Processing Record 40 of Set 1  | vila franca do campo
# Processing Record 41 of Set 1  | harwich
# Processing Record 42 of Set 1  | yulara
# City not found. Skipping...
# Processing Record 43 of Set 1  | vardo
# Processing Record 44 of Set 1  | taloqan
# Processing Record 45 of Set 1  | mataura
# Processing Record 46 of Set 1  | yarmouth
# Processing Record 47 of Set 1  | ondarroa
# Processing Record 48 of Set 1  | mahendranagar
# Processing Record 49 of Set 1  | iwaki
# Processing Record 50 of Set 1  | cidreira
# City not found. Skipping...
# Processing Record 0 of Set 2  | carnarvon
# Processing Record 0 of Set 2  | hobart
# Processing Record 1 of Set 2  | ilulissat
# Processing Record 2 of Set 2  | solnechnyy
# Processing Record 3 of Set 2  | port alfred
# Processing Record 4 of Set 2  | fairbanks
# Processing Record 5 of Set 2  | esperance
# Processing Record 6 of Set 2  | vaini
# Processing Record 7 of Set 2  | ponta do sol
# Processing Record 8 of Set 2  | muravlenko
# Processing Record 9 of Set 2  | nuuk
# Processing Record 10 of Set 2  | provideniya
# Processing Record 11 of Set 2  | atuona
# Processing Record 12 of Set 2  | chuy
# Processing Record 13 of Set 2  | nome
# Processing Record 14 of Set 2  | sabha
# Processing Record 15 of Set 2  | san carlos de bariloche
# Processing Record 16 of Set 2  | wagar
# Processing Record 17 of Set 2  | thompson
# Processing Record 18 of Set 2  | souillac
# Processing Record 19 of Set 2  | mehamn
# Processing Record 20 of Set 2  | saint-philippe
# Processing Record 21 of Set 2  | kavieng
# Processing Record 22 of Set 2  | la rioja
# Processing Record 23 of Set 2  | praia da vitoria
# Processing Record 24 of Set 2  | castro
# Processing Record 25 of Set 2  | fortuna
# Processing Record 26 of Set 2  | yumen
# City not found. Skipping...
# Processing Record 27 of Set 2  | puerto ayora
# Processing Record 28 of Set 2  | victoria
# Processing Record 29 of Set 2  | ihosy
# Processing Record 30 of Set 2  | nizhniy kuranakh
# City not found. Skipping...
# Processing Record 31 of Set 2  | nieuwpoort
# Processing Record 32 of Set 2  | isla mujeres
# Processing Record 33 of Set 2  | jamestown
# Processing Record 34 of Set 2  | virginia beach
# Processing Record 35 of Set 2  | kaitangata
# Processing Record 36 of Set 2  | yenangyaung
# Processing Record 37 of Set 2  | meulaboh
# Processing Record 38 of Set 2  | brebu
# Processing Record 39 of Set 2  | yellowknife
# Processing Record 40 of Set 2  | mughal sarai
# Processing Record 41 of Set 2  | kungurtug
# Processing Record 42 of Set 2  | hamilton
# Processing Record 43 of Set 2  | yerbogachen
# Processing Record 44 of Set 2  | khatanga
# Processing Record 45 of Set 2  | hasaki
# Processing Record 46 of Set 2  | saint george
# Processing Record 47 of Set 2  | qaanaaq
# Processing Record 48 of Set 2  | cayenne
# Processing Record 49 of Set 2  | dakar
# Processing Record 50 of Set 2  | lerwick
# Processing Record 0 of Set 3  | bathsheba
# Processing Record 0 of Set 3  | gimbi
# Processing Record 1 of Set 3  | funtua
# Processing Record 2 of Set 3  | tyristrand
# Processing Record 3 of Set 3  | ola
# Processing Record 4 of Set 3  | angoche
# Processing Record 5 of Set 3  | airai
# Processing Record 6 of Set 3  | mar del plata
# City not found. Skipping...
# Processing Record 7 of Set 3  | qaqortoq
# Processing Record 8 of Set 3  | plettenberg bay
# City not found. Skipping...
# Processing Record 9 of Set 3  | dunedin
# Processing Record 10 of Set 3  | ribeira grande
# Processing Record 11 of Set 3  | la palma
# Processing Record 12 of Set 3  | paamiut
# Processing Record 13 of Set 3  | touros
# Processing Record 14 of Set 3  | ancud
# Processing Record 15 of Set 3  | torbay
# Processing Record 16 of Set 3  | bouna
# Processing Record 17 of Set 3  | danesti
# City not found. Skipping...
# Processing Record 18 of Set 3  | cranbrook
# Processing Record 19 of Set 3  | skjervoy
# Processing Record 20 of Set 3  | marystown
# Processing Record 21 of Set 3  | suez
# Processing Record 22 of Set 3  | yar-sale
# Processing Record 23 of Set 3  | sao joao da barra
# City not found. Skipping...
# Processing Record 24 of Set 3  | limon
# Processing Record 25 of Set 3  | samsun
# Processing Record 26 of Set 3  | lebu
# Processing Record 27 of Set 3  | atbasar
# Processing Record 28 of Set 3  | portland
# Processing Record 29 of Set 3  | houston
# Processing Record 30 of Set 3  | norman wells
# Processing Record 31 of Set 3  | arraial do cabo
# Processing Record 32 of Set 3  | rocha
# Processing Record 33 of Set 3  | mount gambier
# Processing Record 34 of Set 3  | guerrero negro
# Processing Record 35 of Set 3  | kutum
# Processing Record 36 of Set 3  | tuktoyaktuk
# City not found. Skipping...
# Processing Record 37 of Set 3  | cabo san lucas
# Processing Record 38 of Set 3  | havoysund
# Processing Record 39 of Set 3  | petatlan
# Processing Record 40 of Set 3  | georgetown
# Processing Record 41 of Set 3  | ahipara
# Processing Record 42 of Set 3  | igrim
# Processing Record 43 of Set 3  | mpigi
# Processing Record 44 of Set 3  | sola
# Processing Record 45 of Set 3  | bystrice nad pernstejnem
# Processing Record 46 of Set 3  | eyl
# Processing Record 47 of Set 3  | batemans bay
# Processing Record 48 of Set 3  | broome
# Processing Record 49 of Set 3  | fort nelson
# Processing Record 50 of Set 3  | urucui
# Processing Record 0 of Set 4  | boulder city
# Processing Record 0 of Set 4  | mariental
# Processing Record 1 of Set 4  | upernavik
# City not found. Skipping...
# Processing Record 2 of Set 4  | griffith
# City not found. Skipping...
# Processing Record 3 of Set 4  | ngunguru
# Processing Record 4 of Set 4  | ugoofaaru
# Processing Record 5 of Set 4  | barrow
# Processing Record 6 of Set 4  | leh
# Processing Record 7 of Set 4  | bambous virieux
# Processing Record 8 of Set 4  | pevek
# Processing Record 9 of Set 4  | gigmoto
# Processing Record 10 of Set 4  | zhuhai
# Processing Record 11 of Set 4  | tingo maria
# City not found. Skipping...
# Processing Record 12 of Set 4  | palmer
# City not found. Skipping...
# Processing Record 13 of Set 4  | morro bay
# Processing Record 14 of Set 4  | shimoda
# Processing Record 15 of Set 4  | tinglev
# City not found. Skipping...
# Processing Record 16 of Set 4  | puerto carreno
# Processing Record 17 of Set 4  | geraldton
# Processing Record 18 of Set 4  | dongsheng
# Processing Record 19 of Set 4  | ustye
# Processing Record 20 of Set 4  | bredasdorp
# Processing Record 21 of Set 4  | bara
# Processing Record 22 of Set 4  | san rafael
# Processing Record 23 of Set 4  | trairi
# Processing Record 24 of Set 4  | seoul
# Processing Record 25 of Set 4  | shingu
# Processing Record 26 of Set 4  | aykhal
# Processing Record 27 of Set 4  | ostrovnoy
# Processing Record 28 of Set 4  | san patricio
# Processing Record 29 of Set 4  | ust-maya
# Processing Record 30 of Set 4  | manado
# City not found. Skipping...
# Processing Record 31 of Set 4  | saint-augustin
# Processing Record 32 of Set 4  | tiksi
# Processing Record 33 of Set 4  | lake cowichan
# Processing Record 34 of Set 4  | preeceville
# Processing Record 35 of Set 4  | iqaluit
# Processing Record 36 of Set 4  | belmonte
# Processing Record 37 of Set 4  | coihaique
# Processing Record 38 of Set 4  | nador
# Processing Record 39 of Set 4  | yenagoa
# Processing Record 40 of Set 4  | orlik
# Processing Record 41 of Set 4  | maceio
# Processing Record 42 of Set 4  | alofi
# Processing Record 43 of Set 4  | kavaratti
# Processing Record 44 of Set 4  | luderitz
# City not found. Skipping...
# Processing Record 45 of Set 4  | hearst
# Processing Record 46 of Set 4  | vao
# Processing Record 47 of Set 4  | lasa
# Processing Record 48 of Set 4  | severo-kurilsk
# Processing Record 49 of Set 4  | lhokseumawe
# Processing Record 50 of Set 4  | salalah
# Processing Record 0 of Set 5  | ashland
# City not found. Skipping...
# Processing Record 0 of Set 5  | babahoyo
# Processing Record 1 of Set 5  | adre
# Processing Record 2 of Set 5  | tromso
# Processing Record 3 of Set 5  | victor harbor
# Processing Record 4 of Set 5  | buala
# Processing Record 5 of Set 5  | coahuayana
# City not found. Skipping...
# Processing Record 6 of Set 5  | eichstatt
# Processing Record 7 of Set 5  | aklavik
# Processing Record 8 of Set 5  | hilo
# Processing Record 9 of Set 5  | roma
# Processing Record 10 of Set 5  | turukhansk
# Processing Record 11 of Set 5  | lompoc
# Processing Record 12 of Set 5  | atambua
# Processing Record 13 of Set 5  | saldanha
# Processing Record 14 of Set 5  | cap malheureux
# Processing Record 15 of Set 5  | luena
# Processing Record 16 of Set 5  | boundiali
# Processing Record 17 of Set 5  | perelyub
# Processing Record 18 of Set 5  | waingapu
# Processing Record 19 of Set 5  | chiredzi
# Processing Record 20 of Set 5  | taoudenni
# City not found. Skipping...
# Processing Record 21 of Set 5  | kenai
# Processing Record 22 of Set 5  | vanavara
# Processing Record 23 of Set 5  | oriximina
# Processing Record 24 of Set 5  | nanortalik
# Processing Record 25 of Set 5  | ambulu
# Processing Record 26 of Set 5  | colares
# Processing Record 27 of Set 5  | zheshart
# Processing Record 28 of Set 5  | panzhihua
# Processing Record 29 of Set 5  | sitka
# City not found. Skipping...
# Processing Record 30 of Set 5  | ambon
# Processing Record 31 of Set 5  | nishihara
# Processing Record 32 of Set 5  | port macquarie
# Processing Record 33 of Set 5  | port elizabeth
# Processing Record 34 of Set 5  | champerico
# Processing Record 35 of Set 5  | marsa matruh
# City not found. Skipping...
# Processing Record 36 of Set 5  | padang
# Processing Record 37 of Set 5  | orlovskiy
# Processing Record 38 of Set 5  | jinchang
# Processing Record 39 of Set 5  | alice springs
# Processing Record 40 of Set 5  | codrington
# Processing Record 41 of Set 5  | merauke
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 of Set 5  | kiruna
# Processing Record 43 of Set 5  | bethel
# Processing Record 44 of Set 5  | tigil
# City not found. Skipping...
# Processing Record 45 of Set 5  | darnah
# Processing Record 46 of Set 5  | bilma
# Processing Record 47 of Set 5  | bridlington
# Processing Record 48 of Set 5  | nouakchott
# Processing Record 49 of Set 5  | maldonado
# City not found. Skipping...
# Processing Record 50 of Set 5  | berlevag
# Processing Record 0 of Set 6  | tasiilaq
# Processing Record 0 of Set 6  | komatipoort
# City not found. Skipping...
# Processing Record 1 of Set 6  | kihei
# Processing Record 2 of Set 6  | muros
# Processing Record 3 of Set 6  | panguna
# City not found. Skipping...
# Processing Record 4 of Set 6  | nara
# Processing Record 5 of Set 6  | zhangjiakou
# Processing Record 6 of Set 6  | leninskoye
# Processing Record 7 of Set 6  | sovetskiy
# Processing Record 8 of Set 6  | mount isa
# City not found. Skipping...
# Processing Record 9 of Set 6  | katsuura
# Processing Record 10 of Set 6  | saurimo
# Processing Record 11 of Set 6  | santa maria
# Processing Record 12 of Set 6  | havelock
# Processing Record 13 of Set 6  | rongcheng
# Processing Record 14 of Set 6  | yamachiche
# Processing Record 15 of Set 6  | bemidji
# Processing Record 16 of Set 6  | omboue
# Processing Record 17 of Set 6  | guanica
# Processing Record 18 of Set 6  | port shepstone
# Processing Record 19 of Set 6  | port lincoln
# Processing Record 20 of Set 6  | baoning
# Processing Record 21 of Set 6  | karpathos
# Processing Record 22 of Set 6  | vilhena
# Processing Record 23 of Set 6  | belaya gora
# Processing Record 24 of Set 6  | hobyo
# City not found. Skipping...
# Processing Record 25 of Set 6  | sur
# Processing Record 26 of Set 6  | maues
# Processing Record 27 of Set 6  | rawson
# Processing Record 28 of Set 6  | verkhoyansk
# Processing Record 29 of Set 6  | sooke
# Processing Record 30 of Set 6  | longyearbyen
# Processing Record 31 of Set 6  | san jose
# Processing Record 32 of Set 6  | dingle
# Processing Record 33 of Set 6  | atar
# Processing Record 34 of Set 6  | lavrentiya
# City not found. Skipping...
# Processing Record 35 of Set 6  | ca mau
# Processing Record 36 of Set 6  | novoagansk
# Processing Record 37 of Set 6  | lagoa
# Processing Record 38 of Set 6  | caxito
# Processing Record 39 of Set 6  | san cristobal
# City not found. Skipping...
# Processing Record 40 of Set 6  | caborca
# Processing Record 41 of Set 6  | margate
# Processing Record 42 of Set 6  | mizan teferi
# Processing Record 43 of Set 6  | newport
# Processing Record 44 of Set 6  | micheweni
# Processing Record 45 of Set 6  | nemuro
# City not found. Skipping...
# Processing Record 46 of Set 6  | oistins
# Processing Record 47 of Set 6  | itoman
# Processing Record 48 of Set 6  | karratha
# City not found. Skipping...
# Processing Record 49 of Set 6  | silver city
# Processing Record 50 of Set 6  | lardos
# Processing Record 0 of Set 7  | thinadhoo
# Processing Record 0 of Set 7  | gravdal
# Processing Record 1 of Set 7  | lenoir city
# Processing Record 2 of Set 7  | saint-pierre
# Processing Record 3 of Set 7  | clyde river
# Processing Record 4 of Set 7  | syamzha
# Processing Record 5 of Set 7  | de-kastri
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 6 of Set 7  | asuncion
# Processing Record 7 of Set 7  | lucea
# Processing Record 8 of Set 7  | emerald
# Processing Record 9 of Set 7  | tazovskiy
# Processing Record 10 of Set 7  | berdigestyakh
# Processing Record 11 of Set 7  | bani
# City not found. Skipping...
# Processing Record 12 of Set 7  | hay river
# Processing Record 13 of Set 7  | nyurba
# Processing Record 14 of Set 7  | bandarbeyla
# Processing Record 15 of Set 7  | flinders
# Processing Record 16 of Set 7  | visnes
# Processing Record 17 of Set 7  | akdepe
# Processing Record 18 of Set 7  | vredendal
# Processing Record 19 of Set 7  | perth
# Processing Record 20 of Set 7  | xixiang
# Processing Record 21 of Set 7  | mahebourg
# Processing Record 22 of Set 7  | at-bashi
# Processing Record 23 of Set 7  | lakes entrance
# Processing Record 24 of Set 7  | slave lake
# Processing Record 25 of Set 7  | rome
# City not found. Skipping...
# Processing Record 26 of Set 7  | ciudad del maiz
# Processing Record 27 of Set 7  | kisangani
# Processing Record 28 of Set 7  | luganville
# Processing Record 29 of Set 7  | nikitinskiy
# Processing Record 30 of Set 7  | vengerovo
# Processing Record 31 of Set 7  | faya
# Processing Record 32 of Set 7  | inhambane
# Processing Record 33 of Set 7  | northam
# City not found. Skipping...
# Processing Record 34 of Set 7  | batticaloa
# Processing Record 35 of Set 7  | gladstone
# Processing Record 36 of Set 7  | jishui
# Processing Record 37 of Set 7  | salinopolis
# Processing Record 38 of Set 7  | aripuana
# Processing Record 39 of Set 7  | tevaitoa
# Processing Record 40 of Set 7  | kvitok
# Processing Record 41 of Set 7  | richards bay
# Processing Record 42 of Set 7  | ulladulla
# Processing Record 43 of Set 7  | nauta
# Processing Record 44 of Set 7  | ucluelet
# City not found. Skipping...
# Processing Record 45 of Set 7  | agnibilekrou
# Processing Record 46 of Set 7  | kafue
# Processing Record 47 of Set 7  | svetlogorsk
# Processing Record 48 of Set 7  | luxor
# City not found. Skipping...
# Processing Record 49 of Set 7  | port hedland
# Processing Record 50 of Set 7  | darlawn
# Processing Record 0 of Set 8  | dryden
# Processing Record 0 of Set 8  | nakamura
# Processing Record 1 of Set 8  | broken hill
# Processing Record 2 of Set 8  | takoradi
# Processing Record 3 of Set 8  | dyersburg
# Processing Record 4 of Set 8  | genhe
# Processing Record 5 of Set 8  | gimli
# Processing Record 6 of Set 8  | kahului
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 7 of Set 8  | west bay
# City not found. Skipping...
# Processing Record 8 of Set 8  | shelburne
# Processing Record 9 of Set 8  | tacuarembo
# Processing Record 10 of Set 8  | kloulklubed
# Processing Record 11 of Set 8  | ketchikan
# Processing Record 12 of Set 8  | llallagua
# Processing Record 13 of Set 8  | deputatskiy
# Processing Record 14 of Set 8  | sungaipenuh
# Processing Record 15 of Set 8  | santa fe
# Processing Record 16 of Set 8  | tessalit
# Processing Record 17 of Set 8  | pochutla
# Processing Record 18 of Set 8  | menongue
# Processing Record 19 of Set 8  | tabou
# Processing Record 20 of Set 8  | sturgeon falls
# Processing Record 21 of Set 8  | jiazi
# Processing Record 22 of Set 8  | lipany
# Processing Record 23 of Set 8  | mahbubnagar
# City not found. Skipping...
# Processing Record 24 of Set 8  | vestmanna
# Processing Record 25 of Set 8  | basud
# Processing Record 26 of Set 8  | lima
# Processing Record 27 of Set 8  | gat
# Processing Record 28 of Set 8  | sobolevo
# Processing Record 29 of Set 8  | mahibadhoo
# City not found. Skipping...
# Processing Record 30 of Set 8  | port hardy
# City not found. Skipping...
# Processing Record 31 of Set 8  | bang saphan
# Processing Record 32 of Set 8  | prince rupert
# Processing Record 33 of Set 8  | badnawar
# Processing Record 34 of Set 8  | naberera
# Processing Record 35 of Set 8  | santa
# Processing Record 36 of Set 8  | sorland
# Processing Record 37 of Set 8  | mitsamiouli
# Processing Record 38 of Set 8  | nikolskoye
# City not found. Skipping...
# Processing Record 39 of Set 8  | marawi
# Processing Record 40 of Set 8  | formosa
# Processing Record 41 of Set 8  | luorong
# Processing Record 42 of Set 8  | abu samrah
# Processing Record 43 of Set 8  | cravo norte
# Processing Record 44 of Set 8  | aberdeen
# City not found. Skipping...
# Processing Record 45 of Set 8  | namatanai
# Processing Record 46 of Set 8  | xushan
# Processing Record 47 of Set 8  | aswan
# Processing Record 48 of Set 8  | isangel
# City not found. Skipping...
# Processing Record 49 of Set 8  | nelson bay
# Processing Record 50 of Set 8  | pacific grove
# Processing Record 0 of Set 9  | treinta y tres
# Processing Record 0 of Set 9  | celestun
# Processing Record 1 of Set 9  | devarkonda
# Processing Record 2 of Set 9  | bo phloi
# Processing Record 3 of Set 9  | the pas
# Processing Record 4 of Set 9  | sidney
# Processing Record 5 of Set 9  | namibe
# Processing Record 6 of Set 9  | kysyl-syr
# Processing Record 7 of Set 9  | bereda
# City not found. Skipping...
# Processing Record 8 of Set 9  | beringovskiy
# Processing Record 9 of Set 9  | husavik
# Processing Record 10 of Set 9  | manama
# Processing Record 11 of Set 9  | norfolk
# Processing Record 12 of Set 9  | arlit
# Processing Record 13 of Set 9  | tomatlan
# Processing Record 14 of Set 9  | sabang
# City not found. Skipping...
# Processing Record 15 of Set 9  | kruisfontein
# Processing Record 16 of Set 9  | ginir
# Processing Record 17 of Set 9  | klaksvik
# Processing Record 18 of Set 9  | oum hadjer
# Processing Record 19 of Set 9  | leibnitz
# Processing Record 20 of Set 9  | matamoros
# Processing Record 21 of Set 9  | panormos
# Processing Record 22 of Set 9  | maymyo
# City not found. Skipping...
# Processing Record 23 of Set 9  | saint anthony
# Processing Record 24 of Set 9  | los llanos de aridane
# Processing Record 25 of Set 9  | upington
# Processing Record 26 of Set 9  | acajutla
# Processing Record 27 of Set 9  | zamora
# Processing Record 28 of Set 9  | naze
# Processing Record 29 of Set 9  | semnan
# Processing Record 30 of Set 9  | portoferraio
# Processing Record 31 of Set 9  | naryan-mar
# Processing Record 32 of Set 9  | palmares
# Processing Record 33 of Set 9  | grand-lahou
# Processing Record 34 of Set 9  | coolum beach
# Processing Record 35 of Set 9  | nuevo imperial
# Processing Record 36 of Set 9  | gari
# Processing Record 37 of Set 9  | beloha
# Processing Record 38 of Set 9  | camapua
# Processing Record 39 of Set 9  | siocon
# Processing Record 40 of Set 9  | linxia
# Processing Record 41 of Set 9  | launceston
# City not found. Skipping...
# Processing Record 42 of Set 9  | strezhevoy
# Processing Record 43 of Set 9  | kayerkan
# City not found. Skipping...
# Processing Record 44 of Set 9  | maumere
# Processing Record 45 of Set 9  | anito
# Processing Record 46 of Set 9  | saint-georges
# Processing Record 47 of Set 9  | haines junction
# City not found. Skipping...
# Processing Record 48 of Set 9  | waitati
# Processing Record 49 of Set 9  | tuatapere
# Processing Record 50 of Set 9  | mortka
# Processing Record 0 of Set 10  | mackay
# Processing Record 0 of Set 10  | kirillov
# Processing Record 1 of Set 10  | san policarpo
# Processing Record 2 of Set 10  | vila velha
# Processing Record 3 of Set 10  | buraydah
# Processing Record 4 of Set 10  | durango
# Processing Record 5 of Set 10  | mabaruma
# Processing Record 6 of Set 10  | olden
# Processing Record 7 of Set 10  | kirakira
# Processing Record 8 of Set 10  | kibala
# Processing Record 9 of Set 10  | muli
# Processing Record 10 of Set 10  | harrisburg
# Processing Record 11 of Set 10  | bijar
# Processing Record 12 of Set 10  | assare
# Processing Record 13 of Set 10  | tarnos
# Processing Record 14 of Set 10  | roald
# Processing Record 15 of Set 10  | cherskiy
# Processing Record 16 of Set 10  | kununurra
# Processing Record 17 of Set 10  | polunochnoye
# Processing Record 18 of Set 10  | mitu
# City not found. Skipping...
# Processing Record 19 of Set 10  | andapa
# Processing Record 20 of Set 10  | piravam
# Processing Record 21 of Set 10  | guane
# Processing Record 22 of Set 10  | hvide sande
# Processing Record 23 of Set 10  | leshukonskoye
# City not found. Skipping...
# Processing Record 24 of Set 10  | domsod
# Processing Record 25 of Set 10  | wilmington
# Processing Record 26 of Set 10  | la union
# Processing Record 27 of Set 10  | great yarmouth
# Processing Record 28 of Set 10  | chaohu
# Processing Record 29 of Set 10  | boa vista
# Processing Record 30 of Set 10  | pangody
# Processing Record 31 of Set 10  | bela
# City not found. Skipping...
# Processing Record 32 of Set 10  | the valley
# Processing Record 33 of Set 10  | javanrud
# Processing Record 34 of Set 10  | bilibino
# Processing Record 35 of Set 10  | port-gentil
# Processing Record 36 of Set 10  | sao filipe
# Processing Record 37 of Set 10  | buluang
# Processing Record 38 of Set 10  | byron bay
# Processing Record 39 of Set 10  | kaveripattinam
# Processing Record 40 of Set 10  | montijo
# Processing Record 41 of Set 10  | rivera
# Processing Record 42 of Set 10  | rio grande
# Processing Record 43 of Set 10  | marsh harbour
# Processing Record 44 of Set 10  | prabumulih
# Processing Record 45 of Set 10  | skegness
# Processing Record 46 of Set 10  | banda aceh
# Processing Record 47 of Set 10  | diriamba
# Processing Record 48 of Set 10  | arman
# Processing Record 49 of Set 10  | olean
# Processing Record 50 of Set 10  | maromitsa
# Processing Record 0 of Set 11  | kebumen
# Processing Record 0 of Set 11  | mehran
# Processing Record 1 of Set 11  | evensk
# Processing Record 2 of Set 11  | bam
# Processing Record 3 of Set 11  | maebaru
# Processing Record 4 of Set 11  | huarmey
# Processing Record 5 of Set 11  | okha
# Processing Record 6 of Set 11  | lodja
# Processing Record 7 of Set 11  | altay
# Processing Record 8 of Set 11  | qianjiang
# Processing Record 9 of Set 11  | qandala
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 10 of Set 11  | minab
# Processing Record 11 of Set 11  | lorengau
# Processing Record 12 of Set 11  | karaton
# Processing Record 13 of Set 11  | dubti
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dataframe for city weather
weather_df = np.array(city_name)
weather_df = pd.DataFrame(weather_df)
weather_df.columns = ["City"]

# Add columns of longitude, temperature, wind speed, cloudiness, humidity, and date
weather_df["Lat"] = lat
weather_df["Lon"] = lon
weather_df["Temp"] = temp
weather_df["Wind Speed"] = wind_speed
weather_df["Cloud"] = cloud
weather_df["Humidity"] = humidity
weather_df["Date"] = pd.to_datetime('today').date()

weather_df.count()
# Out:
# City          534
# Lat           534
# Lon           534
# Temp          534
# Wind Speed    534
# Cloud         534
# Humidity      534
# Date          534
# dtype: int64

# %%
# Save dataframe to csv
weather_df.to_csv("weather.csv")

# Display first 5 rows of dataframe
weather_df.head()
# Out:
#             City    Lat     Lon    Temp  Wind Speed  Cloud  Humidity  \
# 0          Roura   4.73  -52.33  305.15        6.70     17        59
# 1   Rio Gallegos -51.62  -69.22  288.15        8.70     96        30
# 2      Saskylakh  71.97  114.09  253.94        2.90     77        94
# 3  Leningradskiy  69.38  178.42  262.81        3.15      0        71
# 4      Cape Town -33.93   18.42  288.23        7.20     20        67
#
#          Date
# 0  2019-10-30
# 1  2019-10-30
# 2  2019-10-30
# 3  2019-10-30
# 4  2019-10-30

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Set x axis
x_axis = weather_df["Lat"]

# Plot latitude vs. temperature
plt.scatter(x_axis, weather_df["Temp"], marker="o", edgecolors="black")

# Set x and y limits
plt.xlim(min(weather_df["Lat"])-5, max(weather_df["Lat"])+5)
plt.ylim(min(weather_df["Temp"])-10, max(weather_df["Temp"])+10)

# Set a Title and labels
plt.title("Latitude vs. Temperature ({})".format(weather_df["Date"][0]))
plt.xlabel("Latitude")
plt.ylabel("Current temperature (F)")

# Add grids to plot
plt.grid()

# Save our graph and show the grap
plt.tight_layout()
plt.savefig("Images/temp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(x_axis, weather_df["Humidity"], marker="o", edgecolors="black")

# Set x and y limits
plt.xlim(min(weather_df["Lat"])-5, max(weather_df["Lat"])+5)
plt.ylim(min(weather_df["Humidity"]) - 10, max(weather_df["Humidity"])+10)

# Set a Title and labels
plt.title("Latitude vs. Humidity ({})".format(weather_df["Date"][0]))
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Add grids to plot
plt.grid()

# Save our graph and show the grap
plt.tight_layout()
plt.savefig("Images/humidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Scatter plot latitude vs. cloudiness
plt.scatter(x_axis, weather_df["Cloud"], marker="o", edgecolors="black")

# Set x and y limits
plt.xlim(min(weather_df["Lat"])-5, max(weather_df["Lat"]+5))
plt.ylim(min(weather_df["Cloud"])-10, max(weather_df["Cloud"])+10)

# Set a Title and labels
plt.title("Latitude vs. Cloudiness ({})".format(weather_df["Date"][0]))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

# Add grids to plot
plt.grid()

# Save our graph and show the grap
plt.tight_layout()
plt.savefig("Images/cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Scatter plot latitude vs. wind speed
plt.scatter(x_axis, weather_df["Wind Speed"], marker="o", edgecolors="black", alpha = 0.75)

# Set x and y limits
plt.xlim(min(weather_df["Lat"])-5, max(weather_df["Lat"]+5))
plt.ylim(min(weather_df["Wind Speed"])-2, max(weather_df["Wind Speed"])+2)

# Set a Title and labels
plt.title("Latitude vs. Wind Speed ({})".format(weather_df["Date"][0]))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Add grids to plot
plt.grid()

# Save our graph and show the grap
plt.tight_layout()
plt.savefig("Images/wind.png")
plt.show()

# %% [markdown]
# # Three observations:
#
# * Current temperature is higher when closer to the equator.
#
# * Cloudiness does not seem to correlate with the latitude (closeness to equator).
#
# * In most cities, wind speed is below 6 mph.
