# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 619

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
# Out:
# 'Paris'

# %%
record = 0
set = 1
city_name =[]
lat = []
lon = []
temp = []
cloud = []
humidity = []
wind_speed = []
date = []

# Print header of log
print("Beginning Data Retrieval")
print("-----------------------------")

for city in cities:
    query_url = url + "&q=" + city.capitalize() +"&APPID=" + api_key
   
    # Request weather
    pull = requests.get(query_url).json()
    
    # Pull information from the api if city weather available in the api
    try:
        
        # Store latitude, temp, cloudiness, and wind speed in separate variables
#         city_name.append(pull["name"])
        lat.append(pull["coord"]["lat"])
        lon.append(pull["coord"]["lon"])
        temp.append(pull["main"]["temp"])
        cloud.append(pull["clouds"]["all"])
        humidity.append(pull["main"]["humidity"])
        wind_speed.append(pull["wind"]["speed"])
        date.append(time.ctime(pull["dt"]))        
        
        # Keep record count, group 50 records in each set
        # Print out the record no. in each set, set number, and city name
        if record <= 50:
            print(f"Processing Record {record} of Set {set}  | {city}")
            record += 1
        else:
            record = 0
            set += 1
            print(f"Processing Record {record} of Set {set}  | {city}")
    
    # Print a message when city data is not found
    except KeyError:
        print("City not found. Skipping...")

# Print end of log
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0 of Set 1  | yakovlevka
# Processing Record 1 of Set 1  | saldanha
# Processing Record 2 of Set 1  | tromso
# Processing Record 3 of Set 1  | elizabeth city
# Processing Record 4 of Set 1  | qaanaaq
# Processing Record 5 of Set 1  | punta arenas
# Processing Record 6 of Set 1  | evensk
# Processing Record 7 of Set 1  | khatanga
# Processing Record 8 of Set 1  | khandyga
# Processing Record 9 of Set 1  | vaini
# Processing Record 10 of Set 1  | cherskiy
# Processing Record 11 of Set 1  | mataura
# Processing Record 12 of Set 1  | kushiro
# Processing Record 13 of Set 1  | rikitea
# Processing Record 14 of Set 1  | hare bay
# Processing Record 15 of Set 1  | kurilsk
# Processing Record 16 of Set 1  | thompson
# Processing Record 17 of Set 1  | enid
# Processing Record 18 of Set 1  | pitimbu
# Processing Record 19 of Set 1  | mtambile
# Processing Record 20 of Set 1  | hobart
# Processing Record 21 of Set 1  | kainantu
# Processing Record 22 of Set 1  | dikson
# Processing Record 23 of Set 1  | uyuni
# Processing Record 24 of Set 1  | morant bay
# Processing Record 25 of Set 1  | hasaki
# Processing Record 26 of Set 1  | la paz
# Processing Record 27 of Set 1  | constitucion
# Processing Record 28 of Set 1  | ushuaia
# Processing Record 29 of Set 1  | hithadhoo
# Processing Record 30 of Set 1  | alofi
# Processing Record 31 of Set 1  | pringsewu
# Processing Record 32 of Set 1  | acajutla
# Processing Record 33 of Set 1  | puerto ayora
# Processing Record 34 of Set 1  | urambo
# Processing Record 35 of Set 1  | cockburn town
# Processing Record 36 of Set 1  | hermanus
# City not found. Skipping...
# Processing Record 37 of Set 1  | katsuura
# Processing Record 38 of Set 1  | busselton
# Processing Record 39 of Set 1  | mathathane
# City not found. Skipping...
# Processing Record 40 of Set 1  | mount gambier
# Processing Record 41 of Set 1  | sorland
# Processing Record 42 of Set 1  | batagay-alyta
# Processing Record 43 of Set 1  | avarua
# Processing Record 44 of Set 1  | nouadhibou
# City not found. Skipping...
# Processing Record 45 of Set 1  | atuona
# Processing Record 46 of Set 1  | edd
# Processing Record 47 of Set 1  | butaritari
# Processing Record 48 of Set 1  | leningradskiy
# Processing Record 49 of Set 1  | the valley
# Processing Record 50 of Set 1  | cururupu
# Processing Record 0 of Set 2  | dingle
# City not found. Skipping...
# Processing Record 0 of Set 2  | yellowknife
# Processing Record 1 of Set 2  | meulaboh
# Processing Record 2 of Set 2  | preston
# Processing Record 3 of Set 2  | van
# Processing Record 4 of Set 2  | hilo
# Processing Record 5 of Set 2  | saint pete beach
# Processing Record 6 of Set 2  | bambous virieux
# Processing Record 7 of Set 2  | san patricio
# Processing Record 8 of Set 2  | bluff
# Processing Record 9 of Set 2  | general roca
# Processing Record 10 of Set 2  | alice springs
# City not found. Skipping...
# Processing Record 11 of Set 2  | lorengau
# Processing Record 12 of Set 2  | souillac
# City not found. Skipping...
# Processing Record 13 of Set 2  | barrow
# Processing Record 14 of Set 2  | bredasdorp
# Processing Record 15 of Set 2  | goderich
# Processing Record 16 of Set 2  | port lincoln
# Processing Record 17 of Set 2  | roald
# Processing Record 18 of Set 2  | berlevag
# City not found. Skipping...
# Processing Record 19 of Set 2  | tuktoyaktuk
# Processing Record 20 of Set 2  | waipawa
# Processing Record 21 of Set 2  | kruisfontein
# Processing Record 22 of Set 2  | bethel
# Processing Record 23 of Set 2  | longyearbyen
# Processing Record 24 of Set 2  | albany
# Processing Record 25 of Set 2  | kivsharivka
# Processing Record 26 of Set 2  | upernavik
# Processing Record 27 of Set 2  | severo-kurilsk
# Processing Record 28 of Set 2  | rawson
# Processing Record 29 of Set 2  | santa isabel do rio negro
# Processing Record 30 of Set 2  | airai
# Processing Record 31 of Set 2  | new norfolk
# Processing Record 32 of Set 2  | mahebourg
# Processing Record 33 of Set 2  | vila velha
# Processing Record 34 of Set 2  | lukovetskiy
# Processing Record 35 of Set 2  | hervey bay
# City not found. Skipping...
# Processing Record 36 of Set 2  | kaitangata
# Processing Record 37 of Set 2  | arraial do cabo
# Processing Record 38 of Set 2  | te anau
# Processing Record 39 of Set 2  | talnakh
# Processing Record 40 of Set 2  | iqaluit
# Processing Record 41 of Set 2  | kapaa
# Processing Record 42 of Set 2  | kotma
# Processing Record 43 of Set 2  | bubaque
# Processing Record 44 of Set 2  | shakiso
# Processing Record 45 of Set 2  | luza
# Processing Record 46 of Set 2  | muros
# Processing Record 47 of Set 2  | nikolskoye
# Processing Record 48 of Set 2  | adrar
# City not found. Skipping...
# Processing Record 49 of Set 2  | mandalgovi
# Processing Record 50 of Set 2  | carnarvon
# City not found. Skipping...
# Processing Record 0 of Set 3  | mendota
# City not found. Skipping...
# Processing Record 0 of Set 3  | qianan
# Processing Record 1 of Set 3  | pacific grove
# Processing Record 2 of Set 3  | ryotsu
# Processing Record 3 of Set 3  | gimbi
# Processing Record 4 of Set 3  | shache
# Processing Record 5 of Set 3  | samarai
# Processing Record 6 of Set 3  | port alfred
# City not found. Skipping...
# Processing Record 7 of Set 3  | shimoda
# Processing Record 8 of Set 3  | cape town
# Processing Record 9 of Set 3  | half moon bay
# Processing Record 10 of Set 3  | saint george
# Processing Record 11 of Set 3  | ishigaki
# Processing Record 12 of Set 3  | georgetown
# Processing Record 13 of Set 3  | saint-cyr-sur-loire
# Processing Record 14 of Set 3  | tres arroyos
# Processing Record 15 of Set 3  | miri
# Processing Record 16 of Set 3  | poum
# Processing Record 17 of Set 3  | castro
# Processing Record 18 of Set 3  | parsons
# Processing Record 19 of Set 3  | norman wells
# Processing Record 20 of Set 3  | geraldton
# Processing Record 21 of Set 3  | kodiak
# Processing Record 22 of Set 3  | antofagasta
# City not found. Skipping...
# Processing Record 23 of Set 3  | balkanabat
# Processing Record 24 of Set 3  | nyirbator
# Processing Record 25 of Set 3  | tilichiki
# Processing Record 26 of Set 3  | mirabad
# Processing Record 27 of Set 3  | san policarpo
# Processing Record 28 of Set 3  | takoradi
# Processing Record 29 of Set 3  | kalakamati
# Processing Record 30 of Set 3  | hamilton
# Processing Record 31 of Set 3  | great falls
# Processing Record 32 of Set 3  | inirida
# Processing Record 33 of Set 3  | tevriz
# Processing Record 34 of Set 3  | dengzhou
# Processing Record 35 of Set 3  | besikduzu
# Processing Record 36 of Set 3  | buala
# Processing Record 37 of Set 3  | tasiilaq
# Processing Record 38 of Set 3  | scarborough
# Processing Record 39 of Set 3  | erenhot
# Processing Record 40 of Set 3  | along
# Processing Record 41 of Set 3  | lasa
# Processing Record 42 of Set 3  | cabedelo
# Processing Record 43 of Set 3  | chicama
# Processing Record 44 of Set 3  | ruteng
# Processing Record 45 of Set 3  | sioux lookout
# Processing Record 46 of Set 3  | jamestown
# Processing Record 47 of Set 3  | yerbogachen
# Processing Record 48 of Set 3  | dormidontovka
# Processing Record 49 of Set 3  | izazi
# City not found. Skipping...
# Processing Record 50 of Set 3  | lebu
# Processing Record 0 of Set 4  | qesarya
# Processing Record 0 of Set 4  | hoquiam
# Processing Record 1 of Set 4  | pevek
# Processing Record 2 of Set 4  | ancud
# Processing Record 3 of Set 4  | kant
# Processing Record 4 of Set 4  | usinsk
# Processing Record 5 of Set 4  | gouyave
# City not found. Skipping...
# Processing Record 6 of Set 4  | indianola
# Processing Record 7 of Set 4  | chokurdakh
# Processing Record 8 of Set 4  | lagoa
# Processing Record 9 of Set 4  | portland
# Processing Record 10 of Set 4  | kokubu
# Processing Record 11 of Set 4  | saraland
# Processing Record 12 of Set 4  | gallup
# Processing Record 13 of Set 4  | matara
# Processing Record 14 of Set 4  | fershampenuaz
# Processing Record 15 of Set 4  | ekhabi
# Processing Record 16 of Set 4  | menongue
# Processing Record 17 of Set 4  | porto empedocle
# Processing Record 18 of Set 4  | shingu
# Processing Record 19 of Set 4  | miranda
# Processing Record 20 of Set 4  | istisu
# Processing Record 21 of Set 4  | la ronge
# City not found. Skipping...
# Processing Record 22 of Set 4  | port blair
# Processing Record 23 of Set 4  | altamira
# Processing Record 24 of Set 4  | amalapuram
# Processing Record 25 of Set 4  | manta
# Processing Record 26 of Set 4  | narsaq
# Processing Record 27 of Set 4  | makakilo city
# Processing Record 28 of Set 4  | saint anthony
# Processing Record 29 of Set 4  | havre-saint-pierre
# Processing Record 30 of Set 4  | ozerne
# Processing Record 31 of Set 4  | salalah
# Processing Record 32 of Set 4  | harper
# Processing Record 33 of Set 4  | nanortalik
# Processing Record 34 of Set 4  | chuy
# Processing Record 35 of Set 4  | voskresenskoye
# Processing Record 36 of Set 4  | mahajanga
# Processing Record 37 of Set 4  | port elizabeth
# Processing Record 38 of Set 4  | ridgetown
# Processing Record 39 of Set 4  | jinchang
# Processing Record 40 of Set 4  | trinidad
# Processing Record 41 of Set 4  | aykhal
# Processing Record 42 of Set 4  | shiyan
# Processing Record 43 of Set 4  | arlit
# Processing Record 44 of Set 4  | kununurra
# City not found. Skipping...
# Processing Record 45 of Set 4  | srednekolymsk
# Processing Record 46 of Set 4  | ibra
# Processing Record 47 of Set 4  | port macquarie
# Processing Record 48 of Set 4  | karangasem
# Processing Record 49 of Set 4  | monreal
# Processing Record 50 of Set 4  | deputatskiy
# City not found. Skipping...
# Processing Record 0 of Set 5  | atar
# Processing Record 0 of Set 5  | kahului
# Processing Record 1 of Set 5  | san jeronimo
# Processing Record 2 of Set 5  | arica
# Processing Record 3 of Set 5  | bilibino
# Processing Record 4 of Set 5  | hualmay
# Processing Record 5 of Set 5  | mar del plata
# City not found. Skipping...
# Processing Record 6 of Set 5  | ribeira grande
# Processing Record 7 of Set 5  | cabo san lucas
# Processing Record 8 of Set 5  | igarka
# Processing Record 9 of Set 5  | lobito
# Processing Record 10 of Set 5  | college
# Processing Record 11 of Set 5  | craigieburn
# Processing Record 12 of Set 5  | yumen
# Processing Record 13 of Set 5  | anchorage
# Processing Record 14 of Set 5  | teahupoo
# Processing Record 15 of Set 5  | komsomolskiy
# Processing Record 16 of Set 5  | zubtsov
# Processing Record 17 of Set 5  | provideniya
# Processing Record 18 of Set 5  | kozachi laheri
# Processing Record 19 of Set 5  | shimanovsk
# Processing Record 20 of Set 5  | faanui
# City not found. Skipping...
# Processing Record 21 of Set 5  | torbat-e jam
# Processing Record 22 of Set 5  | shelburne
# City not found. Skipping...
# Processing Record 23 of Set 5  | port moresby
# Processing Record 24 of Set 5  | eunice
# City not found. Skipping...
# Processing Record 25 of Set 5  | victoria
# Processing Record 26 of Set 5  | san carlos
# Processing Record 27 of Set 5  | san ignacio
# Processing Record 28 of Set 5  | birao
# Processing Record 29 of Set 5  | tokur
# City not found. Skipping...
# Processing Record 30 of Set 5  | barra do corda
# Processing Record 31 of Set 5  | ossora
# Processing Record 32 of Set 5  | amapa
# Processing Record 33 of Set 5  | cerveteri
# Processing Record 34 of Set 5  | carballo
# City not found. Skipping...
# Processing Record 35 of Set 5  | sangueya
# Processing Record 36 of Set 5  | vryburg
# Processing Record 37 of Set 5  | glendive
# Processing Record 38 of Set 5  | maceio
# Processing Record 39 of Set 5  | vera cruz
# Processing Record 40 of Set 5  | sistranda
# Processing Record 41 of Set 5  | fare
# Processing Record 42 of Set 5  | horsham
# Processing Record 43 of Set 5  | vizinga
# City not found. Skipping...
# Processing Record 44 of Set 5  | saskylakh
# Processing Record 45 of Set 5  | cairns
# Processing Record 46 of Set 5  | bassila
# Processing Record 47 of Set 5  | cayenne
# Processing Record 48 of Set 5  | victor harbor
# Processing Record 49 of Set 5  | benguela
# Processing Record 50 of Set 5  | agadir
# Processing Record 0 of Set 6  | chanika
# Processing Record 0 of Set 6  | ucluelet
# Processing Record 1 of Set 6  | touros
# City not found. Skipping...
# Processing Record 2 of Set 6  | yulara
# Processing Record 3 of Set 6  | fortuna
# City not found. Skipping...
# Processing Record 4 of Set 6  | okhotsk
# Processing Record 5 of Set 6  | hameenlinna
# Processing Record 6 of Set 6  | mackay
# Processing Record 7 of Set 6  | zhigansk
# Processing Record 8 of Set 6  | santeramo in colle
# Processing Record 9 of Set 6  | kargasok
# City not found. Skipping...
# Processing Record 10 of Set 6  | jugsalai
# Processing Record 11 of Set 6  | baiao
# City not found. Skipping...
# Processing Record 12 of Set 6  | shilka
# Processing Record 13 of Set 6  | oksfjord
# Processing Record 14 of Set 6  | pontes e lacerda
# Processing Record 15 of Set 6  | sao filipe
# Processing Record 16 of Set 6  | rakaia
# Processing Record 17 of Set 6  | boende
# Processing Record 18 of Set 6  | chanal
# Processing Record 19 of Set 6  | kavieng
# Processing Record 20 of Set 6  | basqal
# Processing Record 21 of Set 6  | vardo
# Processing Record 22 of Set 6  | novoomskiy
# City not found. Skipping...
# Processing Record 23 of Set 6  | syamzha
# Processing Record 24 of Set 6  | richards bay
# Processing Record 25 of Set 6  | rovaniemi
# Processing Record 26 of Set 6  | mattru
# Processing Record 27 of Set 6  | contamana
# Processing Record 28 of Set 6  | wanning
# Processing Record 29 of Set 6  | torbay
# Processing Record 30 of Set 6  | conceicao da barra
# City not found. Skipping...
# Processing Record 31 of Set 6  | padang
# Processing Record 32 of Set 6  | egvekinot
# Processing Record 33 of Set 6  | paita
# Processing Record 34 of Set 6  | villa bruzual
# Processing Record 35 of Set 6  | waddan
# Processing Record 36 of Set 6  | marzuq
# Processing Record 37 of Set 6  | tadpatri
# Processing Record 38 of Set 6  | kasongo-lunda
# Processing Record 39 of Set 6  | broken hill
# Processing Record 40 of Set 6  | vagay
# Processing Record 41 of Set 6  | caravelas
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 of Set 6  | paamiut
# Processing Record 43 of Set 6  | kysyl-syr
# Processing Record 44 of Set 6  | xixiang
# Processing Record 45 of Set 6  | avera
# Processing Record 46 of Set 6  | santiago del estero
# Processing Record 47 of Set 6  | cehegin
# Processing Record 48 of Set 6  | gornopravdinsk
# Processing Record 49 of Set 6  | toora-khem
# Processing Record 50 of Set 6  | vyartsilya
# Processing Record 0 of Set 7  | bonthe
# City not found. Skipping...
# Processing Record 0 of Set 7  | ponta do sol
# Processing Record 1 of Set 7  | coahuayana
# Processing Record 2 of Set 7  | ilulissat
# Processing Record 3 of Set 7  | kontagora
# Processing Record 4 of Set 7  | weihe
# Processing Record 5 of Set 7  | aguimes
# Processing Record 6 of Set 7  | singkang
# Processing Record 7 of Set 7  | vostok
# Processing Record 8 of Set 7  | saint-philippe
# Processing Record 9 of Set 7  | nome
# Processing Record 10 of Set 7  | corinto
# Processing Record 11 of Set 7  | teshie
# Processing Record 12 of Set 7  | nelson bay
# Processing Record 13 of Set 7  | la cruz
# Processing Record 14 of Set 7  | ocos
# Processing Record 15 of Set 7  | xining
# Processing Record 16 of Set 7  | hambantota
# Processing Record 17 of Set 7  | plattsburgh
# City not found. Skipping...
# Processing Record 18 of Set 7  | antsohihy
# Processing Record 19 of Set 7  | nuuk
# Processing Record 20 of Set 7  | sungaipenuh
# Processing Record 21 of Set 7  | broome
# Processing Record 22 of Set 7  | itoman
# City not found. Skipping...
# Processing Record 23 of Set 7  | shetpe
# Processing Record 24 of Set 7  | nantucket
# Processing Record 25 of Set 7  | banda aceh
# Processing Record 26 of Set 7  | port hardy
# Processing Record 27 of Set 7  | cidreira
# Processing Record 28 of Set 7  | nara
# City not found. Skipping...
# Processing Record 29 of Set 7  | ewo
# Processing Record 30 of Set 7  | kavaratti
# Processing Record 31 of Set 7  | baykit
# Processing Record 32 of Set 7  | fez
# Processing Record 33 of Set 7  | fort nelson
# Processing Record 34 of Set 7  | mazatlan
# Processing Record 35 of Set 7  | zunyi
# Processing Record 36 of Set 7  | east london
# Processing Record 37 of Set 7  | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 7  | calama
# Processing Record 39 of Set 7  | itarema
# Processing Record 40 of Set 7  | xinqing
# Processing Record 41 of Set 7  | eureka
# Processing Record 42 of Set 7  | binzhou
# Processing Record 43 of Set 7  | korycany
# Processing Record 44 of Set 7  | ust-barguzin
# Processing Record 45 of Set 7  | yazman
# Processing Record 46 of Set 7  | lewistown
# Processing Record 47 of Set 7  | oistins
# Processing Record 48 of Set 7  | dawlatabad
# City not found. Skipping...
# Processing Record 49 of Set 7  | andapa
# Processing Record 50 of Set 7  | isangel
# Processing Record 0 of Set 8  | pouebo
# Processing Record 0 of Set 8  | camacha
# Processing Record 1 of Set 8  | warangal
# Processing Record 2 of Set 8  | clyde river
# Processing Record 3 of Set 8  | tiksi
# Processing Record 4 of Set 8  | cachoeira do sul
# Processing Record 5 of Set 8  | yar-sale
# Processing Record 6 of Set 8  | capaci
# Processing Record 7 of Set 8  | logrono
# Processing Record 8 of Set 8  | ostrovnoy
# Processing Record 9 of Set 8  | honningsvag
# Processing Record 10 of Set 8  | puerto colombia
# Processing Record 11 of Set 8  | evanston
# Processing Record 12 of Set 8  | vestmanna
# Processing Record 13 of Set 8  | tlanalapan
# Processing Record 14 of Set 8  | kendari
# Processing Record 15 of Set 8  | olinda
# Processing Record 16 of Set 8  | silvania
# Processing Record 17 of Set 8  | north bend
# Processing Record 18 of Set 8  | trumbull
# City not found. Skipping...
# Processing Record 19 of Set 8  | auki
# Processing Record 20 of Set 8  | tiznit
# City not found. Skipping...
# Processing Record 21 of Set 8  | zhuhai
# Processing Record 22 of Set 8  | helong
# Processing Record 23 of Set 8  | odienne
# Processing Record 24 of Set 8  | udachnyy
# Processing Record 25 of Set 8  | kurchum
# City not found. Skipping...
# Processing Record 26 of Set 8  | impfondo
# Processing Record 27 of Set 8  | zhangjiakou
# Processing Record 28 of Set 8  | payakumbuh
# Processing Record 29 of Set 8  | saint andrews
# Processing Record 30 of Set 8  | bud
# Processing Record 31 of Set 8  | hearst
# Processing Record 32 of Set 8  | jos
# Processing Record 33 of Set 8  | quesnel
# Processing Record 34 of Set 8  | gimli
# Processing Record 35 of Set 8  | san andres
# Processing Record 36 of Set 8  | ixtapa
# Processing Record 37 of Set 8  | saint-joseph
# Processing Record 38 of Set 8  | vestmannaeyjar
# Processing Record 39 of Set 8  | conakry
# City not found. Skipping...
# Processing Record 40 of Set 8  | phan thiet
# Processing Record 41 of Set 8  | kiunga
# Processing Record 42 of Set 8  | praia da vitoria
# Processing Record 43 of Set 8  | lavrentiya
# Processing Record 44 of Set 8  | saint-pierre
# Processing Record 45 of Set 8  | luderitz
# Processing Record 46 of Set 8  | alyangula
# Processing Record 47 of Set 8  | panama city
# Processing Record 48 of Set 8  | oussouye
# Processing Record 49 of Set 8  | dzhebariki-khaya
# Processing Record 50 of Set 8  | klaksvik
# Processing Record 0 of Set 9  | boguchany
# Processing Record 0 of Set 9  | bumba
# Processing Record 1 of Set 9  | nalut
# Processing Record 2 of Set 9  | zruc nad sazavou
# Processing Record 3 of Set 9  | yugorsk
# Processing Record 4 of Set 9  | chippewa falls
# Processing Record 5 of Set 9  | tommot
# Processing Record 6 of Set 9  | san cristobal
# City not found. Skipping...
# Processing Record 7 of Set 9  | woodward
# City not found. Skipping...
# Processing Record 8 of Set 9  | parati
# Processing Record 9 of Set 9  | mogadishu
# Processing Record 10 of Set 9  | vung tau
# City not found. Skipping...
# Processing Record 11 of Set 9  | sibolga
# Processing Record 12 of Set 9  | mahanoro
# Processing Record 13 of Set 9  | pisco
# Processing Record 14 of Set 9  | rocha
# Processing Record 15 of Set 9  | mineiros
# Processing Record 16 of Set 9  | serenje
# Processing Record 17 of Set 9  | calvinia
# Processing Record 18 of Set 9  | husavik
# Processing Record 19 of Set 9  | gushikawa
# City not found. Skipping...
# Processing Record 20 of Set 9  | ketchikan
# Processing Record 21 of Set 9  | picton
# Processing Record 22 of Set 9  | arman
# Processing Record 23 of Set 9  | jumla
# City not found. Skipping...
# Processing Record 24 of Set 9  | mangalia
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 25 of Set 9  | diplo
# Processing Record 26 of Set 9  | port lavaca
# Processing Record 27 of Set 9  | bom jardim
# Processing Record 28 of Set 9  | wanaka
# City not found. Skipping...
# Processing Record 29 of Set 9  | christchurch
# City not found. Skipping...
# Processing Record 30 of Set 9  | gbarnga
# Processing Record 31 of Set 9  | rapid valley
# Processing Record 32 of Set 9  | dwarka
# Processing Record 33 of Set 9  | shamary
# City not found. Skipping...
# Processing Record 34 of Set 9  | minab
# Processing Record 35 of Set 9  | chapais
# Processing Record 36 of Set 9  | san vicente
# Processing Record 37 of Set 9  | sidhi
# Processing Record 38 of Set 9  | skelleftea
# Processing Record 39 of Set 9  | grindavik
# Processing Record 40 of Set 9  | wasilla
# Processing Record 41 of Set 9  | mamit
# Processing Record 42 of Set 9  | culebra
# Processing Record 43 of Set 9  | verkh-usugli
# Processing Record 44 of Set 9  | dongsheng
# City not found. Skipping...
# Processing Record 45 of Set 9  | marawi
# Processing Record 46 of Set 9  | bathsheba
# Processing Record 47 of Set 9  | cape girardeau
# Processing Record 48 of Set 9  | florianopolis
# City not found. Skipping...
# Processing Record 49 of Set 9  | westport
# Processing Record 50 of Set 9  | dunedin
# City not found. Skipping...
# Processing Record 0 of Set 10  | bilma
# Processing Record 0 of Set 10  | gubkinskiy
# Processing Record 1 of Set 10  | sile
# Processing Record 2 of Set 10  | prainha
# Processing Record 3 of Set 10  | biak
# Processing Record 4 of Set 10  | mufumbwe
# Processing Record 5 of Set 10  | grand forks
# Processing Record 6 of Set 10  | hofn
# Processing Record 7 of Set 10  | myitkyina
# Processing Record 8 of Set 10  | vao
# Processing Record 9 of Set 10  | anloga
# Processing Record 10 of Set 10  | zhanaozen
# Processing Record 11 of Set 10  | matsubase
# City not found. Skipping...
# Processing Record 12 of Set 10  | aklavik
# Processing Record 13 of Set 10  | dossor
# Processing Record 14 of Set 10  | ligayan
# Processing Record 15 of Set 10  | pingliang
# Processing Record 16 of Set 10  | linares
# Processing Record 17 of Set 10  | vangaindrano
# City not found. Skipping...
# Processing Record 18 of Set 10  | fomboni
# Processing Record 19 of Set 10  | cap-aux-meules
# Processing Record 20 of Set 10  | freeport
# Processing Record 21 of Set 10  | boa vista
# Processing Record 22 of Set 10  | tierranueva
# Processing Record 23 of Set 10  | vokhtoga
# Processing Record 24 of Set 10  | seryshevo
# Processing Record 25 of Set 10  | thinadhoo
# City not found. Skipping...
# Processing Record 26 of Set 10  | jalu
# Processing Record 27 of Set 10  | nizhniy odes
# Processing Record 28 of Set 10  | kungurtug
# Processing Record 29 of Set 10  | kieta
# Processing Record 30 of Set 10  | marathon
# Processing Record 31 of Set 10  | nuzvid
# Processing Record 32 of Set 10  | dehui
# Processing Record 33 of Set 10  | wattegama
# Processing Record 34 of Set 10  | fairbanks
# Processing Record 35 of Set 10  | faya
# Processing Record 36 of Set 10  | wahiawa
# Processing Record 37 of Set 10  | sitka
# Processing Record 38 of Set 10  | hope
# Processing Record 39 of Set 10  | callaway
# City not found. Skipping...
# Processing Record 40 of Set 10  | mehamn
# Processing Record 41 of Set 10  | jardim
# Processing Record 42 of Set 10  | esperance
# Processing Record 43 of Set 10  | moshupa
# Processing Record 44 of Set 10  | devils lake
# Processing Record 45 of Set 10  | urengoy
# Processing Record 46 of Set 10  | duvan
# Processing Record 47 of Set 10  | toguchin
# Processing Record 48 of Set 10  | posse
# Processing Record 49 of Set 10  | hami
# Processing Record 50 of Set 10  | inhambane
# Processing Record 0 of Set 11  | wahpeton
# Processing Record 0 of Set 11  | byron bay
# Processing Record 1 of Set 11  | morondava
# Processing Record 2 of Set 11  | los llanos de aridane
# Processing Record 3 of Set 11  | berezovyy
# Processing Record 4 of Set 11  | vrede
# Processing Record 5 of Set 11  | luanda
# Processing Record 6 of Set 11  | kholodnyy
# Processing Record 7 of Set 11  | taltal
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 8 of Set 11  | gerash
# Processing Record 9 of Set 11  | bariri
# Processing Record 10 of Set 11  | barentu
# Processing Record 11 of Set 11  | jasper
# Processing Record 12 of Set 11  | marsh harbour
# Processing Record 13 of Set 11  | peniche
# Processing Record 14 of Set 11  | vimperk
# Processing Record 15 of Set 11  | puerto palomas
# Processing Record 16 of Set 11  | kirakira
# City not found. Skipping...
# Processing Record 17 of Set 11  | chabahar
# Processing Record 18 of Set 11  | corning
# City not found. Skipping...
# Processing Record 19 of Set 11  | tafresh
# Processing Record 20 of Set 11  | myingyan
# Processing Record 21 of Set 11  | abu dhabi
# Processing Record 22 of Set 11  | solnechnyy
# Processing Record 23 of Set 11  | batemans bay
# Processing Record 24 of Set 11  | turayf
# Processing Record 25 of Set 11  | truckee
# Processing Record 26 of Set 11  | wheeling
# Processing Record 27 of Set 11  | anadyr
# City not found. Skipping...
# Processing Record 28 of Set 11  | lata
# Processing Record 29 of Set 11  | atambua
# Processing Record 30 of Set 11  | margate
# Processing Record 31 of Set 11  | antalaha
# Processing Record 32 of Set 11  | sangar
# Processing Record 33 of Set 11  | santa marta
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dataframe for city weather
weather_df = np.array(city_name)
weather_df = pd.DataFrame(weather_df)
weather_df.columns = ["City"]

# Add columns of longitude, temperature, wind speed, cloudiness, humidity, and date
weather_df["Lat"] = lat
weather_df["Lon"] = lon
weather_df["Temp"] = temp
weather_df["Wind Speed"] = wind_speed
weather_df["Cloud"] = cloud
weather_df["Humidity"] = humidity
weather_df["Date"] = pd.to_datetime('today').date()

weather_df.count()
# Out:
# City            0
# Lat           554
# Lon           554
# Temp          554
# Wind Speed    554
# Cloud         554
# Humidity      554
# Date          554
# dtype: int64

# %%
# Save dataframe to csv
weather_df.to_csv("weather.csv")

# Display first 5 rows of dataframe
weather_df.head()
# Out:
#    City    Lat     Lon    Temp  Wind Speed  Cloud  Humidity        Date
# 0   NaN  44.43  133.47  278.03        3.51     86        89  2019-10-30
# 1   NaN  41.42   -6.55  286.90        1.76     97        95  2019-10-30
# 2   NaN  69.65   18.96  269.59        3.60     75        74  2019-10-30
# 3   NaN  36.30  -76.22  292.16        1.50     40        93  2019-10-30
# 4   NaN  77.48  -69.36  256.92        4.35     26        86  2019-10-30

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Set x axis
x_axis = weather_df["Lat"]

# Plot latitude vs. temperature
plt.scatter(x_axis, weather_df["Temp"], marker="o", edgecolors="black")

# Set x and y limits
plt.xlim(min(weather_df["Lat"])-5, max(weather_df["Lat"])+5)
plt.ylim(min(weather_df["Temp"])-10, max(weather_df["Temp"])+10)

# Set a Title and labels
plt.title("Latitude vs. Temperature ({})".format(weather_df["Date"][0]))
plt.xlabel("Latitude")
plt.ylabel("Current temperature (F)")

# Add grids to plot
plt.grid()

# Save our graph and show the grap
plt.tight_layout()
plt.savefig("Images/temp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(x_axis, weather_df["Humidity"], marker="o", edgecolors="black")

# Set x and y limits
plt.xlim(min(weather_df["Lat"])-5, max(weather_df["Lat"])+5)
plt.ylim(min(weather_df["Humidity"]) - 10, max(weather_df["Humidity"])+10)

# Set a Title and labels
plt.title("Latitude vs. Humidity ({})".format(weather_df["Date"][0]))
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Add grids to plot
plt.grid()

# Save our graph and show the grap
plt.tight_layout()
plt.savefig("Images/humidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Scatter plot latitude vs. cloudiness
plt.scatter(x_axis, weather_df["Cloud"], marker="o", edgecolors="black")

# Set x and y limits
plt.xlim(min(weather_df["Lat"])-5, max(weather_df["Lat"]+5))
plt.ylim(min(weather_df["Cloud"])-10, max(weather_df["Cloud"])+10)

# Set a Title and labels
plt.title("Latitude vs. Cloudiness ({})".format(weather_df["Date"][0]))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

# Add grids to plot
plt.grid()

# Save our graph and show the grap
plt.tight_layout()
plt.savefig("Images/cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Scatter plot latitude vs. wind speed
plt.scatter(x_axis, weather_df["Wind Speed"], marker="o", edgecolors="black", alpha = 0.75)

# Set x and y limits
plt.xlim(min(weather_df["Lat"])-5, max(weather_df["Lat"]+5))
plt.ylim(min(weather_df["Wind Speed"])-2, max(weather_df["Wind Speed"])+2)

# Set a Title and labels
plt.title("Latitude vs. Wind Speed ({})".format(weather_df["Date"][0]))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Add grids to plot
plt.grid()

# Save our graph and show the grap
plt.tight_layout()
plt.savefig("Images/wind.png")
plt.show()
